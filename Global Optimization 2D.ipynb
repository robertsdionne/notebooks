# %%
# %matplotlib inline
import math
import matplotlib
from matplotlib import pyplot as p
import numpy as np
import random

# %%
def Ackley(x0, x1):
    n, a, b, c = 2.0, 20.0, 0.2, 2.0 * math.pi
    s1, s2 = x0**2 + x1**2, np.cos(c * x0) + np.cos(c * x1)
    return -a * np.exp(-b * np.sqrt(1.0 / n * s1)) - np.exp(1.0 / n * s2) + a + math.e

# %%
Ackley(0, 0)
# Out:
# 4.4408920985006262e-16

# %%
x = np.linspace(-15, 30, 1000)
x0, x1 = np.meshgrid(x, x)
y = Ackley(x0, x1)

# %%
p.plot(x, Ackley(x, 0))

# %%
figure, legend = p.subplots()
plot = legend.pcolormesh(x0, x1, y, cmap=matplotlib.cm.RdBu)
cb = figure.colorbar(plot, ax=legend)

# %%
def Deviation(f):
    return lambda alpha, x0, x1: alpha - np.minimum(alpha, f(x0, x1))

# %%
V = Deviation(Ackley)

# %%
x = np.linspace(-15, 30, 1000)
x0, x1 = np.meshgrid(x, x)
y = V(10, x0, x1)

# %%
p.plot(x, V(10, x, 0))

# %%
figure, legend = p.subplots()
plot = legend.pcolormesh(x0, x1, y, cmap=matplotlib.cm.RdBu)
cb = figure.colorbar(plot, ax=legend)

# %%
def Estimator(V, alpha, N, a, b, c, d):
    samples0 = (b - a) * np.random.random_sample(N) + a
    samples1 = (d - c) * np.random.random_sample(N) + c
    return (b - a) * (d - c) / float(N) * V(alpha, samples0, samples1).sum()

# %%
Estimator(V, 0.4, 2**16, -15.0, 30.0, -15.0, 30.0)
# Out:
# 0.0053808117320839925

# %%
# Evaluate the deviation function over \alpha \in (-2, 2)
y = np.linspace(-20, 20, 1000)
alpha = y.copy()
for i in xrange(0, y.size):
    alpha[i] = Estimator(V, y[i], 2**16, -15.0, 30.0, -15.0, 30.0)
p.plot(y, alpha)

# %%
# Binary search over the range of f to find \alpha^*
def FindEssentialInfimum(f, N, a, b, c, d, epsilon):
    V = Deviation(f)
    delta = 1.0
    alpha_max = f((b - a) * np.random.random_sample() + a, (d - c) * np.random.random_sample() + c)
    #print 'alpha_max', alpha_max
    alpha = alpha_max - delta
    alpha_min = -float('inf')
    expand = True
    while expand:
        integral = Estimator(V, alpha, N, a, b, c, d)
        if integral > 0:
            delta *= 2.0
            alpha_max = alpha
            alpha = alpha - delta
        else:
            delta /= 2.0
            alpha_min = alpha
            alpha = alpha + delta
            expand = False
        #print (alpha_min, alpha_max)
    while alpha_max - alpha_min > epsilon:
        integral = Estimator(V, alpha, N, a, b, c, d)
        if integral > 0:
            alpha_max = alpha
        else:
            alpha_min = alpha
        alpha = (alpha_min + alpha_max) / 2.0
        #print (alpha_min, alpha_max)
    return alpha

# %%
FindEssentialInfimum(Ackley, 2**16, -15.0, 30.0, -15.0, 30.0, 1e-10)
# Out:
# 0.13800040338783504

# %%
# Binary search over parameter x to find the subdomain containing the global optimum coordinate x^* and value \alpha^*
def FindMinimizingParameter(f, N, a, b, c, d, epsilon, delta):
#     alpha_star = FindEssentialInfimum(f, N, a, b, c, d, epsilon)
#     print u'\u03b1\u207a', alpha_star
    x0_max = b
    x0_min = a
    x1_max = d
    x1_min = c
    while x0_max - x0_min > epsilon or x1_max - x0_max > epsilon:
        alpha_star = float('inf')
        print
        print u'locating x0\u207a within', (x0_min, x0_max)
        while x0_max - x0_min > epsilon:
            x0 = (x0_min + x0_max) / 2.0
#         alpha_star = min(alpha_star, FindEssentialInfimum(f, N, x0_min, x0_max, c, d, epsilon))
            potential_alpha_star = FindEssentialInfimum(f, N, x0_min, x0_max, x1_min, x1_max, epsilon)
            if potential_alpha_star < alpha_star:
                alpha_star = potential_alpha_star
            else:
                break
            print u'\u03b1\u207a', alpha_star
            alpha_left = FindEssentialInfimum(f, N, x0_min, x0, x1_min, x1_max, epsilon)
            alpha_right = FindEssentialInfimum(f, N, x0, x0_max, x1_min, x1_max, epsilon)
            if abs(alpha_star - alpha_left) < abs(alpha_star - alpha_right):
                x0_max = x0
                print 'x0 in', (x0_min, x0_max), 'dx0', x0_max - x0_min, u'd\u03b1', abs(alpha_star - alpha_left)
#             elif abs(alpha_star - alpha_right) < delta:
            else:
                x0_min = x0
                print 'x0 in', (x0_min, x0_max), 'dx0', x0_max - x0_min, u'd\u03b1', abs(alpha_star - alpha_right)
#             else:
#                 print 'neither', alpha_star, alpha_left, alpha_right
#                 break
        alpha_star = float('inf')
        print
        print u'locating x1\u207a within', (x1_min, x1_max)
        while x1_max - x1_min > epsilon:
            x1 = (x1_min + x1_max) / 2.0
#         alpha_star = min(alpha_star, FindEssentialInfimum(f, N, x0_min, x0_max, x1_min, x1_max, epsilon))
            potential_alpha_star = FindEssentialInfimum(f, N, x0_min, x0_max, x1_min, x1_max, epsilon)
            if potential_alpha_star < alpha_star:
                alpha_star = potential_alpha_star
            else:
                break
            print u'\u03b1\u207a', alpha_star
            alpha_left = FindEssentialInfimum(f, N, x0_min, x0_max, x1_min, x1, epsilon)
            alpha_right = FindEssentialInfimum(f, N, x0_min, x0_max, x1, x1_max, epsilon)
            if abs(alpha_star - alpha_left) < abs(alpha_star - alpha_right):
                x1_max = x1
                print 'x1 in', (x1_min, x1_max), 'dx1', x1_max - x1_min, u'd\u03b1', abs(alpha_star - alpha_left)
#             elif abs(alpha_star - alpha_right) < delta:
            else:
                x1_min = x1
                print 'x1 in', (x1_min, x1_max), 'dx1', x1_max - x1_min, u'd\u03b1', abs(alpha_star - alpha_right)
#             else:
#                 print 'neither', alpha_star, alpha_left, alpha_right
#                 break
    return ((x0_min, x0_max), (x1_min, x1_max))

# %%
FindMinimizingParameter(Ackley, 2**19, -15.0, 30.0, -15.0, 30.0, 1e-10, 1e-1)
# Out:
# locating x0⁺ within (-15.0, 30.0)
# α⁺
#  0.160703678538
# x0 in
#  (-15.0, 7.5) dx0 22.5 dα 0.135140019295
# α⁺
#  0.0832592569209
# x0 in
#  (-3.75, 7.5) dx0 11.25 dα 0.0268261639555
# α⁺
#  0.0433964350621
# x0 in
#  (-3.75, 1.875) dx0 5.625 dα 0.00615300117123
# α⁺
#  0.0155444500357
# x0 in
#  (-0.9375, 1.875) dx0 2.8125 dα 0.0101706701889
# locating x1⁺ within (-15.0, 30.0)
# α⁺
#  0.019834458849
# x1 in
#  (-15.0, 7.5) dx1 22.5 dα 0.0107296574092
# α⁺
#  0.0143337184459
# x1 in
#  (-3.75, 7.5) dx1 11.25 dα 0.000525151772811
# α⁺
#  0.0129160746983
# x1 in
#  (-3.75, 1.875) dx1 5.625 dα 0.00518943743234
# α⁺
#  0.00951032344492
# x1 in
#  (-0.9375, 1.875) dx1 2.8125 dα 0.00439937158268
# α⁺
#  0.00692348310245
# x1 in
#  (-0.9375, 0.46875) dx1 1.40625 dα 0.00366285390416
# α⁺
#  0.00311407443224
# x1 in
#  (-0.234375, 0.46875) dx1 0.703125 dα 0.000599778425563
# α⁺
#  0.00198488612147
# x1 in
#  (-0.234375, 0.1171875) dx1 0.3515625 dα 0.000822081159807
# locating x0⁺ within (-0.9375, 1.875)
# α⁺
#  0.000967132065814
# x0 in
#  (-0.9375, 0.46875) dx0 1.40625 dα 0.000887655677328
# locating x1⁺ within (-0.234375, 0.1171875)
# α⁺
#  0.00134876653585
# x1 in
#  (-0.05859375, 0.1171875) dx1 0.17578125 dα 0.000894798322143
# α⁺
#  0.0011330713769
# x1 in
#  (-0.05859375, 0.029296875) dx1 0.087890625 dα 0.000394731641922
# α⁺
#  0.000827562672822
# x1 in
#  (-0.0146484375, 0.029296875) dx1 0.0439453125 dα 0.000415790213236
# α⁺
#  0.000384482878492
# x1 in
#  (-0.0146484375, 0.00732421875) dx1 0.02197265625 dα 0.000223560420803
# locating x0⁺ within (-0.9375, 0.46875)
# α⁺
#  0.000271153170229
# x0 in
#  (-0.234375, 0.46875) dx0 0.703125 dα 9.76687289516e-05
# α⁺
#  0.000251768365012
# x0 in
#  (-0.234375, 0.1171875) dx0 0.3515625 dα 0.000108572431795
# α⁺
#  0.000188230352617
# x0 in
#  (-0.05859375, 0.1171875) dx0 0.17578125 dα 6.56365709908e-05
# α⁺
#  0.00015705370095
# x0 in
#  (-0.05859375, 0.029296875) dx0 0.087890625 dα 3.26997473827e-05
# α⁺
#  6.5975038265e-05
# x0 in
#  (-0.0146484375, 0.029296875) dx0 0.0439453125 dα 1.1532619947e-05
# α⁺
#  5.57870672222e-05
# x0 in
#  (-0.0146484375, 0.00732421875) dx0 0.02197265625 dα 2.42267622177e-05
# α⁺
#  2.34509422623e-05
# x0 in
#  (-0.003662109375, 0.00732421875) dx0 0.010986328125 dα 2.68472193703e-05
# locating x1⁺ within (-0.0146484375, 0.00732421875)
# α⁺
#  1.16409812887e-05
# x1 in
#  (-0.003662109375, 0.00732421875) dx1 0.010986328125 dα 9.06200056505e-06
# locating x0⁺ within (-0.003662109375, 0.00732421875)
# α⁺
#  1.524981186e-05
# x0 in
#  (-0.003662109375, 0.0018310546875) dx0 0.0054931640625 dα 9.42539898929e-06
# α⁺
#  8.57500074902e-06
# x0 in
#  (-0.00091552734375, 0.0018310546875) dx0 0.00274658203125 dα 1.13040030989e-05
# locating x1⁺ within (-0.003662109375, 0.00732421875)
# α⁺
#  1.27042653131e-05
# x1 in
#  (-0.003662109375, 0.0018310546875) dx1 0.0054931640625 dα 4.74307942611e-06
# α⁺
#  1.04841687905e-05
# x1 in
#  (-0.00091552734375, 0.0018310546875) dx1 0.00274658203125 dα 7.74925510072e-06
# α⁺
#  3.98002163182e-06
# x1 in
#  (-0.00091552734375, 0.000457763671875) dx1 0.00137329101562 dα 1.44470967811e-06
# α⁺
#  3.31721843994e-06
# x1 in
#  (-0.0002288818359375, 0.000457763671875) dx1 0.000686645507812 dα 9.6764622981e-09
# locating x0⁺ within (-0.00091552734375, 0.0018310546875)
# α⁺
#  7.92399764027e-07
# x0 in
#  (-0.00091552734375, 0.000457763671875) dx0 0.00137329101562 dα 1.12437823319e-06
# locating x1⁺ within (-0.0002288818359375, 0.000457763671875)
# α⁺
#  1.61223201944e-06
# x1 in
#  (-0.0002288818359375, 0.00011444091796875) dx1 0.000343322753906 dα 8.41945222874e-07
# α⁺
#  1.60561166895e-06
# x1 in
#  (-5.7220458984375e-05, 0.00011444091796875) dx1 0.000171661376953 dα 7.43119631608e-07
# α⁺
#  8.39727267721e-07
# x1 in
#  (-5.7220458984375e-05, 2.86102294921875e-05) dx1 8.58306884766e-05 dα 1.24715473504e-07
# α⁺
#  7.32313406804e-07
# x1 in
#  (-1.430511474609375e-05, 2.86102294921875e-05) dx1 4.29153442383e-05 dα 1.00303260808e-07
# α⁺
#  2.737943956e-07
# x1 in
#  (-1.430511474609375e-05, 7.152557373046875e-06) dx1 2.14576721191e-05 dα 2.32598491579e-07
# locating x0⁺ within (-0.00091552734375, 0.000457763671875)
# α⁺
#  2.82373893601e-07
# x0 in
#  (-0.0002288818359375, 0.000457763671875) dx0 0.000686645507812 dα 3.77016071695e-08
# α⁺
#  1.93178263164e-07
# x0 in
#  (-0.0002288818359375, 0.00011444091796875) dx0 0.000343322753906 dα 1.02516281686e-07
# α⁺
#  1.299020842e-07
# x0 in
#  (-5.7220458984375e-05, 0.00011444091796875) dx0 0.000171661376953 dα 4.34707310148e-08
# α⁺
#  1.28667747124e-07
# x0 in
#  (-5.7220458984375e-05, 2.86102294921875e-05) dx0 8.58306884766e-05 dα 4.18788985712e-08
# α⁺
#  1.07307954966e-07
# x0 in
#  (-1.430511474609375e-05, 2.86102294921875e-05) dx0 4.29153442383e-05 dα 3.61272967098e-09
# α⁺
#  7.39269307992e-08
# x0 in
#  (-1.430511474609375e-05, 7.152557373046875e-06) dx0 2.14576721191e-05 dα 3.39183330311e-08
# α⁺
#  2.20434057674e-08
# x0 in
#  (-3.5762786865234375e-06, 7.152557373046875e-06) dx0 1.07288360596e-05 dα 1.68399907352e-08
# locating x1⁺ within (-1.430511474609375e-05, 7.152557373046875e-06)
# α⁺
#  3.19421968875e-08
# x1 in
#  (-3.5762786865234375e-06, 7.152557373046875e-06) dx1 1.07288360596e-05 dα 1.57846500315e-08
# α⁺
#  6.8612107107e-09
# x1 in
#  (-3.5762786865234375e-06, 1.7881393432617188e-06) dx1 5.36441802979e-06 dα 1.80467871758e-08
# locating x0⁺ within (-3.5762786865234375e-06, 7.152557373046875e-06)
# α⁺
#  1.92858284898e-08
# x0 in
#  (-3.5762786865234375e-06, 1.7881393432617188e-06) dx0 5.36441802979e-06 dα 1.06029283131e-08
# α⁺
#  9.80321646082e-09
# x0 in
#  (-8.940696716308594e-07, 1.7881393432617188e-06) dx0 2.68220901489e-06 dα 1.48835610503e-09
# α⁺
#  6.98672453225e-09
# x0 in
#  (-8.940696716308594e-07, 4.470348358154297e-07) dx0 1.34110450745e-06 dα 3.96205734887e-09
# α⁺
#  3.35622774017e-09
# x0 in
#  (-2.2351741790771484e-07, 4.470348358154297e-07) dx0 6.70552253723e-07 dα 2.10727435501e-09
# locating x1⁺ within (-3.5762786865234375e-06, 1.7881393432617188e-06)
# α⁺
#  2.4927833131e-09
# x1 in
#  (-8.940696716308594e-07, 1.7881393432617188e-06) dx1 2.68220901489e-06 dα 2.14889439576e-10
# α⁺
#  1.49073686728e-09
# x1 in
#  (-8.940696716308594e-07, 4.470348358154297e-07) dx1 1.34110450745e-06 dα 4.83808548779e-11
# α⁺
#  1.30937083398e-09
# x1 in
#  (-2.2351741790771484e-07, 4.470348358154297e-07) dx1 6.70552253723e-07 dα 2.40071074131e-10
# locating x0⁺ within (-2.2351741790771484e-07, 4.470348358154297e-07)
# α⁺
#  2.01282590595e-09
# x0 in
#  (-2.2351741790771484e-07, 1.1175870895385742e-07) dx0 3.35276126862e-07 dα 1.3093739426e-09
# α⁺
#  2.76085376782e-10
# x0 in
#  (-5.587935447692871e-08, 1.1175870895385742e-07) dx0 1.67638063431e-07 dα 8.24211809913e-10
# locating x1⁺ within (-2.2351741790771484e-07, 4.470348358154297e-07)
# α⁺
#  3.88663767836e-10
# x1 in
#  (-2.2351741790771484e-07, 1.1175870895385742e-07) dx1 3.35276126862e-07 dα 1.87782234207e-10
# locating x0⁺ within (-5.587935447692871e-08, 1.1175870895385742e-07)
# α⁺
#  5.63304514145e-10
# x0 in
#  (-5.587935447692871e-08, 2.7939677238464355e-08) dx0 8.38190317154e-08 dα 1.2279244288e-10
# α⁺
#  3.17446069431e-10
# x0 in
#  (-1.3969838619232178e-08, 2.7939677238464355e-08) dx0 4.19095158577e-08 dα 1.07160502694e-10
# α⁺
#  1.47473588896e-10
# x0 in
#  (-1.3969838619232178e-08, 6.984919309616089e-09) dx0 2.09547579288e-08 dα 4.33431068814e-12
# locating x1⁺ within (-2.2351741790771484e-07, 1.1175870895385742e-07)
# α⁺
#  7.78759279285e-11
# x1 in
#  (-5.587935447692871e-08, 1.1175870895385742e-07) dx1 1.67638063431e-07 dα 2.64108734882e-11
# locating x0⁺ within (-1.3969838619232178e-08, 6.984919309616089e-09)
# α⁺
#  5.58348922652e-11
# x0 in
#  (-3.4924596548080444e-09, 6.984919309616089e-09) dx0 1.04773789644e-08 dα 1.34932065521e-11
# locating x1⁺ within (-5.587935447692871e-08, 1.1175870895385742e-07)
# α⁺
#  8.50737258418e-11
# x1 in
#  (-5.587935447692871e-08, 2.7939677238464355e-08) dx1 8.38190317154e-08 dα 9.94759830064e-13
# α⁺
#  5.10138598031e-11
# x1 in
#  (-1.3969838619232178e-08, 2.7939677238464355e-08) dx1 4.19095158577e-08 dα 6.98427982115e-11
# α⁺
#  2.55622190082e-11
# x1 in
#  (-1.3969838619232178e-08, 6.984919309616089e-09) dx1 2.09547579288e-08 dα 2.95941049444e-12
# locating x0⁺ within (-3.4924596548080444e-09, 6.984919309616089e-09)
# α⁺
#  4.67936800419e-12
# x0 in
#  (-3.4924596548080444e-09, 1.7462298274040222e-09) dx0 5.23868948221e-09 dα 2.09965378417e-12
# α⁺
#  -4.58610927012e-12
# x0 in
#  (-8.731149137020111e-10, 1.7462298274040222e-09) dx0 2.61934474111e-09 dα 2.73985278909e-11
# locating x1⁺ within (-1.3969838619232178e-08, 6.984919309616089e-09)
# α⁺
#  1.29007915461e-12
# x1 in
#  (-3.4924596548080444e-09, 6.984919309616089e-09) dx1 1.04773789644e-08 dα 9.29034627006e-12
# α⁺
#  -1.11834985717e-11
# x1 in
#  (-3.4924596548080444e-09, 1.7462298274040222e-09) dx1 5.23868948221e-09 dα 1.42676981341e-11
# locating x0⁺ within (-8.731149137020111e-10, 1.7462298274040222e-09)
# α⁺
#  -8.96660523608e-12
# x0 in
#  (-8.731149137020111e-10, 4.3655745685100555e-10) dx0 1.30967237055e-09 dα 1.15889520202e-11
# locating x1⁺ within (-3.4924596548080444e-09, 1.7462298274040222e-09)
# α⁺
#  -5.47073497614e-12
# x1 in
#  (-8.731149137020111e-10, 1.7462298274040222e-09) dx1 2.61934474111e-09 dα 6.25988150205e-12
# locating x0⁺ within (-8.731149137020111e-10, 4.3655745685100555e-10)
# α⁺
#  -2.67443844848e-11
# x0 in
#  (-2.1827872842550278e-10, 4.3655745685100555e-10) dx0 6.54836185277e-10 dα 4.59721150037e-12
# locating x1⁺ within (-8.731149137020111e-10, 1.7462298274040222e-09)
# α⁺
#  -2.05058192648e-11
# x1 in
#  (-8.731149137020111e-10, 4.3655745685100555e-10) dx1 1.30967237055e-09 dα 4.61852778244e-13
# locating x0⁺ within (-2.1827872842550278e-10, 4.3655745685100555e-10)
# α⁺
#  1.84390280822e-11
# x0 in
#  (-2.1827872842550278e-10, 1.0913936421275139e-10) dx0 3.27418092638e-10 dα 2.3803181648e-12
# locating x1⁺ within (-8.731149137020111e-10, 4.3655745685100555e-10)
# α⁺
#  2.13309370167e-11
# x1 in
#  (-2.1827872842550278e-10, 4.3655745685100555e-10) dx1 6.54836185277e-10 dα 2.65245603259e-11
# α⁺
#  7.48245909676e-12
# x1 in
#  (-2.1827872842550278e-10, 1.0913936421275139e-10) dx1 3.27418092638e-10 dα 2.58637555817e-12
# α⁺
#  -2.30673258272e-11
# x1 in
#  (-5.4569682106375694e-11, 1.0913936421275139e-10) dx1 1.63709046319e-10 dα 4.82280881897e-11
# locating x0⁺ within (-2.1827872842550278e-10, 1.0913936421275139e-10)
# α⁺
#  8.87157014517e-12
# x0 in
#  (-5.4569682106375694e-11, 1.0913936421275139e-10) dx0 1.63709046319e-10 dα 1.71951342054e-11
# α⁺
#  -4.49373871447e-12
# x0 in
#  (-5.4569682106375694e-11, 2.7284841053187847e-11) dx0 8.18545231596e-11 dα 2.56790144704e-11
#
# locating x1⁺ within (-5.4569682106375694e-11, 1.0913936421275139e-10)
# α⁺
#  -5.41744427096e-12
# x1 in
#  (-5.4569682106375694e-11, 2.7284841053187847e-11) dx1 8.18545231596e-11 dα 3.318234576e-11
# ((-5.4569682106375694e-11, 2.7284841053187847e-11),
#  (-5.4569682106375694e-11, 2.7284841053187847e-11))

# %%
Ackley(-5.4569682106375694e-11, -5.4569682106375694e-11)
# Out:
# 2.1827917251471263e-10
